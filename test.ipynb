# %%
import matplotlib.pyplot as plt
import numpy as np

X = np.arange(1,9,0.01)
def func(x):
    return np.sin(x)

fig, (ax1,ax2) = plt.subplots(2,1)
ax1.plot(X,func(X), 'r', label = "nr 1")
ax2.plot(X,X, label = "nr 2")
fig.legend()
plt.show();
